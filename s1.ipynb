# %% [markdown]
# <a href="https://colab.research.google.com/github/DZMaddy-dev/Colab-Notebook/blob/main/s1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student_name='josh'
student_age=20
student_course='Btech'
print(student_name)
print(student_age)
print(student_course)
print(type(student_name))
print(type(student_age))
print(type(student_course))
mark='89'
mark=int(mark)
print(mark+4)
marks=[78,85,91,26]
subjects = ["Python", "Math", "AI", "Data"]
print(subjects[-1])
print(subjects[0])
student={"name":"aman",
         "age":23,
         "course":'btech',
         "marks":89}
print(student)
my={"name":'Arya',
    'Course':'Btech',
    'favourite':'Python data handling',
    'Confidence score':3}
print(my['name'], my['favourite'])
marks=72
if marks>=26:
  print("pass")
else:
  print("fail")

n=-5
if n>0:
  print("positive")
elif n==0:
  print("0")
else:
  print("negative")
marks=[78,85,91,26]
for i in marks:
  print(i)
marks=[78,35,91,22,72]
for i in marks:
  if i>=40:
    print("pass")
  else:
    print("fail")
marks= [78,35,91,22,72]
for i in marks:
  if i>=75:
    print("strong")
  elif i>=40:
    print("average")
  else:
    print("Need improvement")
students = [
    {"name": "Aarav", "study_hours": 6, "attendance": 85, "marks": 78},
    {"name": "Riya", "study_hours": 3, "attendance": 70, "marks": 55},
    {"name": "Kabir", "study_hours": 8, "attendance": 90, "marks": 88},
    {"name": "Meera", "study_hours": 2, "attendance": 60, "marks": 35}
]
for i in students:
  if i["marks"]>=75:
    print("strong")
  elif i["marks"]>=40:
    print("average")
  else:
    print("need improvement")
for i in students:
  if i["attendance"]<75:
    print("less")
  else:
    print("ok")
for i in students:
  if i['study_hours']<4:
    print("less")
  else:
    print("ok")
# Out:
# josh
# 20
# Btech
# <class 'str'>
# <class 'int'>
# <class 'str'>
# 93
# Data
# Python
# {'name': 'aman', 'age': 23, 'course': 'btech', 'marks': 89}
# Arya Python data handling
# pass
# negative
# 78
# 85
# 91
# 26
# pass
# fail
# pass
# fail
# pass
# strong
# Need improvement
# strong
# Need improvement
# average
# strong
# average
# strong
# need improvement
# ok
# less
# ok
# less
# ok
# less
# ok
# less

# %%
students = [
    {"name": "Aarav", "study_hours": 6, "attendance": 85, "marks": 78},
    {"name": "Riya", "study_hours": 3, "attendance": 70, "marks": 55},
    {"name": "Kabir", "study_hours": 8, "attendance": 90, "marks": 88},
    {"name": "Meera", "study_hours": 2, "attendance": 60, "marks": 35}
]
for i in students:
  if i["marks"]>=75:
    print("strong")
  elif i["marks"]>=40:
    print("average")
  else:
    print("need improvement")
for i in students:
  if i["attendance"]<75:
    print("less")
  else:
    print("ok")
for i in students:
  if i['study_hours']<4:
    print("less")
  else:
    print("ok")
# Out:
# strong
# average
# strong
# need improvement
# ok
# less
# ok
# less
# ok
# less
# ok
# less

# %%
student={
    "name":'arya'
    "marks":88
}
